# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
df_red_wine = pd.read_csv("/Users/Lucasmeissner/Desktop/Blue_Berry_Winery/wine+quality/winequality-red.csv", sep= ';')
df_red_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
df_white_wine = pd.read_csv("/Users/Lucasmeissner/Desktop/Blue_Berry_Winery/wine+quality/winequality-white.csv", sep= ';')
df_white_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %%
df_red_wine.sort_values(by=['quality'],ascending=False).head(100)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 495            10.7              0.35         0.53             2.6      0.070
# 1403            7.2              0.33         0.33             1.7      0.061
# 390             5.6              0.85         0.05             1.4      0.045
# 1061            9.1              0.40         0.50             1.8      0.071
# 1202            8.6              0.42         0.39             1.8      0.068
# ...             ...               ...          ...             ...        ...
# 1147           10.0              0.41         0.45             6.2      0.071
# 1003            6.8              0.36         0.32             1.8      0.067
# 978             7.0              0.40         0.32             3.6      0.061
# 929             8.7              0.33         0.38             3.3      0.063
# 974             8.8              0.33         0.41             5.9      0.073
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 495                   5.0                  16.0  0.99720  3.15       0.65
# 1403                  3.0                  13.0  0.99600  3.23       1.10
# 390                  12.0                  88.0  0.99240  3.56       0.82
# 1061                  7.0                  16.0  0.99462  3.21       0.69
# 1202                  6.0                  12.0  0.99516  3.35       0.69
# ...                   ...                   ...      ...   ...        ...
# 1147                  6.0                  14.0  0.99702  3.21       0.49
# 1003                  4.0                   8.0  0.99280  3.36       0.55
# 978                   9.0                  29.0  0.99416  3.28       0.49
# 929                  10.0                  19.0  0.99468  3.30       0.73
# 974                   7.0                  13.0  0.99658  3.30       0.62
#
#       alcohol  quality
# 495      11.0        8
# 1403     10.0        8
# 390      12.9        8
# 1061     12.5        8
# 1202     11.7        8
# ...       ...      ...
# 1147     11.8        7
# 1003     12.8        7
# 978      11.3        7
# 929      12.0        7
# 974      12.1        7
#
# [100 rows x 12 columns]

# %%
df_red_wine['quality_label'] = df_red_wine['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')

# %%
df_red_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality quality_label
# 0         9.4        5           low
# 1         9.8        5           low
# 2         9.8        5           low
# 3         9.8        6        medium
# 4         9.4        5           low
# ...       ...      ...           ...
# 1594     10.5        5           low
# 1595     11.2        6        medium
# 1596     11.0        6        medium
# 1597     10.2        5           low
# 1598     11.0        6        medium
#
# [1599 rows x 13 columns]

# %%
df_white_wine['quality_label']= df_white_wine['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')

# %%
df_all_wines= pd.concat([df_red_wine[['residual sugar','total sulfur dioxide','sulphates','alcohol','volatile acidity','quality','quality_label']].describe(), df_white_wine[['residual sugar','total sulfur dioxide','sulphates','alcohol','volatile acidity','quality','quality_label']].describe()], axis=1, keys=["Red Wines Stats", "White Wines Stats"])
df_all_wines
# Out:
#       Red Wines Stats                                                 \
#        residual sugar total sulfur dioxide    sulphates      alcohol
# count     1599.000000          1599.000000  1599.000000  1599.000000
# mean         2.538806            46.467792     0.658149    10.422983
# std          1.409928            32.895324     0.169507     1.065668
# min          0.900000             6.000000     0.330000     8.400000
# 25%          1.900000            22.000000     0.550000     9.500000
# 50%          2.200000            38.000000     0.620000    10.200000
# 75%          2.600000            62.000000     0.730000    11.100000
# max         15.500000           289.000000     2.000000    14.900000
#
#                                     White Wines Stats                       \
#       volatile acidity      quality    residual sugar total sulfur dioxide
# count      1599.000000  1599.000000       4898.000000          4898.000000
# mean          0.527821     5.636023          6.391415           138.360657
# std           0.179060     0.807569          5.072058            42.498065
# min           0.120000     3.000000          0.600000             9.000000
# 25%           0.390000     5.000000          1.700000           108.000000
# 50%           0.520000     6.000000          5.200000           134.000000
# 75%           0.640000     6.000000          9.900000           167.000000
# max           1.580000     8.000000         65.800000           440.000000
#
#
#          sulphates      alcohol volatile acidity      quality
# count  4898.000000  4898.000000      4898.000000  4898.000000
# mean      0.489847    10.514267         0.278241     5.877909
# std       0.114126     1.230621         0.100795     0.885639
# min       0.220000     8.000000         0.080000     3.000000
# 25%       0.410000     9.500000         0.210000     5.000000
# 50%       0.470000    10.400000         0.260000     6.000000
# 75%       0.550000    11.400000         0.320000     6.000000
# max       1.080000    14.200000         1.100000     9.000000

# %%
pd.concat([df_red_wine[['residual sugar','quality',]].describe(), df_white_wine[['residual sugar','quality',]].describe()], axis=1, keys=["Red Wines Stats", "White Wines Stats"])

#1 key takeaway is that white wine has a much wider range in sugar residual than red wine due to standard deviation and min/max values
#2 in general all white wines have much higher sugar residual in average than red wines
# Out:
#       Red Wines Stats              White Wines Stats
#        residual sugar      quality    residual sugar      quality
# count     1599.000000  1599.000000       4898.000000  4898.000000
# mean         2.538806     5.636023          6.391415     5.877909
# std          1.409928     0.807569          5.072058     0.885639
# min          0.900000     3.000000          0.600000     3.000000
# 25%          1.900000     5.000000          1.700000     5.000000
# 50%          2.200000     6.000000          5.200000     6.000000
# 75%          2.600000     6.000000          9.900000     6.000000
# max         15.500000     8.000000         65.800000     9.000000

# %%
pd.concat([df_red_wine[['total sulfur dioxide','quality']].describe(), df_white_wine[['total sulfur dioxide','quality']].describe()], axis=1, keys=["Red Wines Stats", "White Wines Stats"])

#legal limits for sulfur dioxides for red wine
#EU = 160mg/L

#legal limits for sulfur dioxides for white wine and rose 
#EU = 210mg/L

#legal limits for sulfur dioxides for sweet wines
#EU = 400mg/L
#US = 350mg/L
#Australia = 250mg/L

#key takeaways
#1 there are legal limits which need to be considered for different regions
#2 there are white and red wine(s) in our dataset which exceed the legal limit of 210mg/L or 160mg/L
#3 need to categorize wine into sweet/rose etc. in order to match them correctly
# Out:
#            Red Wines Stats                 White Wines Stats
#       total sulfur dioxide      quality total sulfur dioxide      quality
# count          1599.000000  1599.000000          4898.000000  4898.000000
# mean             46.467792     5.636023           138.360657     5.877909
# std              32.895324     0.807569            42.498065     0.885639
# min               6.000000     3.000000             9.000000     3.000000
# 25%              22.000000     5.000000           108.000000     5.000000
# 50%              38.000000     6.000000           134.000000     6.000000
# 75%              62.000000     6.000000           167.000000     6.000000
# max             289.000000     8.000000           440.000000     9.000000

# %%
pd.concat([df_red_wine[['sulphates','quality']].describe(), df_white_wine[['sulphates','quality']].describe()], axis=1, keys=["Red Wines Stats", "White Wines Stats"])

### sulfates necessary to make wine but high sulfate is considered to be linked with headache/hangover
### hence the less solphates the higher the quality of wine
###red wine has slightly higher mean in sulphates than white wine and also has the wine with the most sulphates (max) + slightly higher std
# Out:
#       Red Wines Stats              White Wines Stats
#             sulphates      quality         sulphates      quality
# count     1599.000000  1599.000000       4898.000000  4898.000000
# mean         0.658149     5.636023          0.489847     5.877909
# std          0.169507     0.807569          0.114126     0.885639
# min          0.330000     3.000000          0.220000     3.000000
# 25%          0.550000     5.000000          0.410000     5.000000
# 50%          0.620000     6.000000          0.470000     6.000000
# 75%          0.730000     6.000000          0.550000     6.000000
# max          2.000000     8.000000          1.080000     9.000000

# %%
pd.concat([df_red_wine[['alcohol','quality']].describe(), df_white_wine[['alcohol','quality']].describe()], axis=1, keys=["Red Wines Stats", "White Wines Stats"])

### on average (mean) red and white are almost identical in regards to alcohol
### white wine has a slightly higher std
# Out:
#       Red Wines Stats              White Wines Stats
#               alcohol      quality           alcohol      quality
# count     1599.000000  1599.000000       4898.000000  4898.000000
# mean        10.422983     5.636023         10.514267     5.877909
# std          1.065668     0.807569          1.230621     0.885639
# min          8.400000     3.000000          8.000000     3.000000
# 25%          9.500000     5.000000          9.500000     5.000000
# 50%         10.200000     6.000000         10.400000     6.000000
# 75%         11.100000     6.000000         11.400000     6.000000
# max         14.900000     8.000000         14.200000     9.000000

# %%
pd.concat([df_red_wine[['volatile acidity','quality']].describe(), df_white_wine[['volatile acidity','quality']].describe()], axis=1, keys=["Red Wines Stats", "White Wines Stats"])

### process of turning wine into vinegar
### legal limits in US:
### max. 1.2 G/L for red
### max. 1.1 G/L for white

###red wine has on average almost twice as much v.a.
# Out:
#        Red Wines Stats              White Wines Stats
#       volatile acidity      quality  volatile acidity      quality
# count      1599.000000  1599.000000       4898.000000  4898.000000
# mean          0.527821     5.636023          0.278241     5.877909
# std           0.179060     0.807569          0.100795     0.885639
# min           0.120000     3.000000          0.080000     3.000000
# 25%           0.390000     5.000000          0.210000     5.000000
# 50%           0.520000     6.000000          0.260000     6.000000
# 75%           0.640000     6.000000          0.320000     6.000000
# max           1.580000     8.000000          1.100000     9.000000

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Red Wine', 'White Wine'
sizes = [1599, 4898]
explode = (0, 0.1)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
red_whine = df_red_wine
white_whine =df_white_wine

axe1= sns.histplot(data=df_red_wine, x="quality_label")

axe2 = sns.histplot(data=df_white_wine, x="quality_label")

# %%
sns.countplot(x ='quality_label',data=df_white_wine,width=0.8,color= 'grey',order=['low','medium','high'])
# Out:
# <Axes: xlabel='quality_label', ylabel='count'>

# %%
sns.countplot(x ='quality_label',data=red_whine,width=0.8,color= 'red',order=['low','medium','high'])
# Out:
# <Axes: xlabel='quality_label', ylabel='count'>

# %%
fig ,axs = plt.subplots(1,2,figsize=(12,8),sharey=True)
sns.countplot(x ='quality_label',data=df_white_wine,width=0.8,color= 'grey',order=['low','medium','high'],ax=axs[0])
sns.countplot(x ='quality_label',data=red_whine,width=0.8,color= 'red',order=['low','medium','high'],ax=axs[1])
# Out:
# <Axes: xlabel='quality_label', ylabel='count'>

# %%
fig ,axs = plt.subplots(1,2,figsize=(10,4))

sns.boxplot(x= 'quality_label',y ='alcohol',data=df_white_wine,width=0.8,color= 'grey',order=['low','medium','high'],ax=axs[0],palette='deep')
sns.boxplot(x= 'quality_label',y ='pH',data=red_whine,width=0.8,color= 'red',order=['low','medium','high'],ax=axs[1],palette='deep')
# Out:
# <Axes: title={'center': 'Graph'}, xlabel='quality_label', ylabel='pH'>

# %%
fig ,axs = plt.subplots(2,2,figsize=(10,4),sharex=True)

sns.lineplot(data= df_red_wine,x='quality',y='alcohol',ax=axs[0,0],color='blue')
sns.lineplot(data= df_red_wine,x='quality',y='sulphates',ax=axs[0,1],color='red')

sns.lineplot(data= white_whine,x='quality',y='alcohol',ax=axs[1,0],color='blue')
sns.lineplot(data= white_whine,x='quality',y='sulphates',ax=axs[1,1],color='red')
# Out:
# <Axes: xlabel='quality', ylabel='sulphates'>

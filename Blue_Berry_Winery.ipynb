# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt
import matplotlib.pyplot as plt

# %%
df_red_wine = pd.read_csv("/Users/Lucasmeissner/Desktop/Blue_Berry_Winery/wine+quality/winequality-red.csv", sep= ';')
df_red_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df_white_wine = pd.read_csv("/Users/Lucasmeissner/Desktop/Blue_Berry_Winery/wine+quality/winequality-white.csv", sep= ';')
df_white_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df_red_wine.drop_duplicates(inplace=True)
df_red_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df_white_wine.drop_duplicates(inplace=True)
df_white_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 6               6.2              0.32         0.16             7.0      0.045
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df_red_wine.reset_index(inplace=True,drop=True)

# %%
df_red_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1354            6.8             0.620         0.08             1.9      0.068
# 1355            6.2             0.600         0.08             2.0      0.090
# 1356            5.9             0.550         0.10             2.2      0.062
# 1357            5.9             0.645         0.12             2.0      0.075
# 1358            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df_red_wine['quality_label'] = df_red_wine['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')

# %%
df_red_wine['category'] = df_red_wine['residual sugar'].apply(lambda value: 'dry'
if value <= 4 else 'medium dry'
if value <= 12 else 'medium'
if value <= 45 else 'sweet')

# %%
df_red_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1354            6.8             0.620         0.08             1.9      0.068
# 1355            6.2             0.600         0.08             2.0      0.090
# 1356            5.9             0.550         0.10             2.2      0.062
# 1357            5.9             0.645         0.12             2.0      0.075
# 1358            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df_red_wine['category'] = df_red_wine['residual sugar'].apply(lambda value: 'dry'
if value <= 4 else 'medium dry'
if value <= 12 else 'medium'
if value <= 45 else 'sweet')

# %%
df_white_wine['category'] = df_white_wine['residual sugar'].apply(lambda value: 'dry'
if value <= 4 else 'medium dry'
if value <= 12 else 'medium'
if value <= 45 else 'sweet')

# %%
df_red_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1354            6.8             0.620         0.08             1.9      0.068
# 1355            6.2             0.600         0.08             2.0      0.090
# 1356            5.9             0.550         0.10             2.2      0.062
# 1357            5.9             0.645         0.12             2.0      0.075
# 1358            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df_red_wine['type']='red'
df_red_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1354            6.8             0.620         0.08             1.9      0.068
# 1355            6.2             0.600         0.08             2.0      0.090
# 1356            5.9             0.550         0.10             2.2      0.062
# 1357            5.9             0.645         0.12             2.0      0.075
# 1358            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df_red_wine['wine_index']=pd.Series(range(1,1360))
df_red_wine['wine_ID']=df_red_wine.type + "-" + df_red_wine.wine_index.map(str)
df_red_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1354            6.8             0.620         0.08             1.9      0.068
# 1355            6.2             0.600         0.08             2.0      0.090
# 1356            5.9             0.550         0.10             2.2      0.062
# 1357            5.9             0.645         0.12             2.0      0.075
# 1358            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df_white_wine['quality_label']= df_white_wine['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')

# %%
df_white_wine.reset_index(inplace=True,drop=True)
df_white_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               6.2              0.32         0.16             7.0      0.045
# ...             ...               ...          ...             ...        ...
# 3956            6.2              0.21         0.29             1.6      0.039
# 3957            6.6              0.32         0.36             8.0      0.047
# 3958            6.5              0.24         0.19             1.2      0.041
# 3959            5.5              0.29         0.30             1.1      0.022
# 3960            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df_white_wine['type']='white'
df_white_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               6.2              0.32         0.16             7.0      0.045
# ...             ...               ...          ...             ...        ...
# 3956            6.2              0.21         0.29             1.6      0.039
# 3957            6.6              0.32         0.36             8.0      0.047
# 3958            6.5              0.24         0.19             1.2      0.041
# 3959            5.5              0.29         0.30             1.1      0.022
# 3960            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df_white_wine['wine_index']=pd.Series(range(1,3962))
df_white_wine['wine_ID']=df_white_wine.type + "-" + df_white_wine.wine_index.map(str)
df_white_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               6.2              0.32         0.16             7.0      0.045
# ...             ...               ...          ...             ...        ...
# 3956            6.2              0.21         0.29             1.6      0.039
# 3957            6.6              0.32         0.36             8.0      0.047
# 3958            6.5              0.24         0.19             1.2      0.041
# 3959            5.5              0.29         0.30             1.1      0.022
# 3960            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df_all_wines = pd.concat([df_red_wine,df_white_wine])

# %%
df_all_wines
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.66         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 3956            6.2              0.21         0.29             1.6      0.039
# 3957            6.6              0.32         0.36             8.0      0.047
# 3958            6.5              0.24         0.19             1.2      0.041
# 3959            5.5              0.29         0.30             1.1      0.022
# 3960            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
import random as rd

# %%
pd.concat([df_red_wine[['residual sugar','quality',]].describe(), df_white_wine[['residual sugar','quality',]].describe()], axis=1, keys=["Red Wines Stats", "White Wines Stats"])

#1 key takeaway is that white wine has a much wider range in sugar residual than red wine due to standard deviation and min/max values
#2 in general all white wines have much higher sugar residual in average than red wines
# Out:
#       Red Wines Stats              White Wines Stats
#        residual sugar      quality    residual sugar      quality
# count     1359.000000  1359.000000       3961.000000  3961.000000
# mean         2.523400     5.623252          5.914819     5.854835
# std          1.352314     0.823578          4.861646     0.890683
# min          0.900000     3.000000          0.600000     3.000000
# 25%          1.900000     5.000000          1.600000     5.000000
# 50%          2.200000     6.000000          4.700000     6.000000
# 75%          2.600000     6.000000          8.900000     6.000000
# max         15.500000     8.000000         65.800000     9.000000

# %%
sns.countplot(data=df_red_wine,x='category')
# Out:
# <Axes: xlabel='category', ylabel='count'>

# %%
pd.concat([df_red_wine[['total sulfur dioxide','quality']].describe(), df_white_wine[['total sulfur dioxide','quality']].describe()], axis=1, keys=["Red Wines Stats", "White Wines Stats"])

#legal limits for sulfur dioxides for red wine
#EU = 160mg/L

#legal limits for sulfur dioxides for white wine and rose 
#EU = 210mg/L

#legal limits for sulfur dioxides for sweet wines
#EU = 400mg/L
#US = 350mg/L
#Australia = 250mg/L

#key takeaways
#1 there are legal limits which need to be considered for different regions
#2 there are white and red wine(s) in our dataset which exceed the legal limit of 210mg/L or 160mg/L
#3 need to categorize wine into sweet/rose etc. in order to match them correctly
# Out:
#            Red Wines Stats                 White Wines Stats
#       total sulfur dioxide      quality total sulfur dioxide      quality
# count          1359.000000  1359.000000          3961.000000  3961.000000
# mean             46.825975     5.623252           137.193512     5.854835
# std              33.408946     0.823578            43.129065     0.890683
# min               6.000000     3.000000             9.000000     3.000000
# 25%              22.000000     5.000000           106.000000     5.000000
# 50%              38.000000     6.000000           133.000000     6.000000
# 75%              63.000000     6.000000           166.000000     6.000000
# max             289.000000     8.000000           440.000000     9.000000

# %%
pd.concat([df_red_wine[['sulphates','quality']].describe(), df_white_wine[['sulphates','quality']].describe()], axis=1, keys=["Red Wines Stats", "White Wines Stats"])

### sulfates necessary to make wine but high sulfate is considered to be linked with headache/hangover
### hence the less solphates the higher the quality of wine
###red wine has slightly higher mean in sulphates than white wine and also has the wine with the most sulphates (max) + slightly higher std
# Out:
#       Red Wines Stats              White Wines Stats
#             sulphates      quality         sulphates      quality
# count     1359.000000  1359.000000       3961.000000  3961.000000
# mean         0.658705     5.623252          0.490351     5.854835
# std          0.170667     0.823578          0.113523     0.890683
# min          0.330000     3.000000          0.220000     3.000000
# 25%          0.550000     5.000000          0.410000     5.000000
# 50%          0.620000     6.000000          0.480000     6.000000
# 75%          0.730000     6.000000          0.550000     6.000000
# max          2.000000     8.000000          1.080000     9.000000

# %%
pd.concat([df_red_wine[['alcohol','quality']].describe(), df_white_wine[['alcohol','quality']].describe()], axis=1, keys=["Red Wines Stats", "White Wines Stats"])

### on average (mean) red and white are almost identical in regards to alcohol
### white wine has a slightly higher std
# Out:
#       Red Wines Stats              White Wines Stats
#               alcohol      quality           alcohol      quality
# count     1359.000000  1359.000000       3961.000000  3961.000000
# mean        10.432315     5.623252         10.589358     5.854835
# std          1.082065     0.823578          1.217076     0.890683
# min          8.400000     3.000000          8.000000     3.000000
# 25%          9.500000     5.000000          9.500000     5.000000
# 50%         10.200000     6.000000         10.400000     6.000000
# 75%         11.100000     6.000000         11.400000     6.000000
# max         14.900000     8.000000         14.200000     9.000000

# %%
pd.concat([df_red_wine[['volatile acidity','quality']].describe(), df_white_wine[['volatile acidity','quality']].describe()], axis=1, keys=["Red Wines Stats", "White Wines Stats"])

### process of turning wine into vinegar
### legal limits in US:
### max. 1.2 G/L for red
### max. 1.1 G/L for white

###red wine has on average almost twice as much v.a.
# Out:
#        Red Wines Stats              White Wines Stats
#       volatile acidity      quality  volatile acidity      quality
# count      1359.000000  1359.000000       3961.000000  3961.000000
# mean          0.529478     5.623252          0.280538     5.854835
# std           0.183031     0.823578          0.103437     0.890683
# min           0.120000     3.000000          0.080000     3.000000
# 25%           0.390000     5.000000          0.210000     5.000000
# 50%           0.520000     6.000000          0.260000     6.000000
# 75%           0.640000     6.000000          0.330000     6.000000
# max           1.580000     8.000000          1.100000     9.000000

# %%
df_white_wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    3961.000000       3961.000000  3961.000000     3961.000000
# mean        6.839346          0.280538     0.334332        5.914819
# std         0.866860          0.103437     0.122446        4.861646
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.600000
# 50%         6.800000          0.260000     0.320000        4.700000
# 75%         7.300000          0.330000     0.390000        8.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  3961.000000          3961.000000           3961.000000  3961.000000
# mean      0.045905            34.889169            137.193512     0.993790
# std       0.023103            17.210021             43.129065     0.002905
# ...

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Red Wine (Total: 1.359)', 'White Wine (Total: 3.961)'
sizes = [1359, 3961]
explode = (0, 0.1)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90,colors=('darkred','lightgrey'))
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

title= ax1.set_title('Dataset')
title.set_fontsize(20)

plt.show()

# %%
red_wine = df_red_wine
white_wine =df_white_wine

axe1= sns.histplot(data=df_red_wine, x="quality_label")

axe2 = sns.histplot(data=df_white_wine, x="quality_label")

# %%
df_all_wines
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.66         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 3956            6.2              0.21         0.29             1.6      0.039
# 3957            6.6              0.32         0.36             8.0      0.047
# 3958            6.5              0.24         0.19             1.2      0.041
# 3959            5.5              0.29         0.30             1.1      0.022
# 3960            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
sns.histplot(data=df_all_wines,x='quality_label')
# Out:
# <Axes: xlabel='quality_label', ylabel='Count'>

# %%
ax= sns.countplot(x ='quality_label',data=df_all_wines,width=0.8,color= 'grey',order=['low','medium','high'],hue='type',palette=['darkred','lightgrey'])
ax.bar_label(ax.containers[0]),
ax.bar_label(ax.containers[1]),
ax.legend
title = ax.set(title=('Wine Type'))
ax.title.set_fontsize(20)

# %%
ax= sns.countplot(x ='category',data=df_all_wines,width=0.8,color= 'grey',order=['dry','medium dry','medium','sweet'],hue='type',palette=['darkred','lightgrey'])
ax.bar_label(ax.containers[0]),
ax.bar_label(ax.containers[1]),
ax.legend
title = ax.set(title=('Wine Category'))
ax.title.set_fontsize(20)

# %%
ax= sns.countplot(x ='quality_label',data=df_all_wines,width=0.8,color= 'grey',order=['low','medium','high'],hue='type',palette=['darkred','lightgrey'])
ax.bar_label(ax.containers[0]),
ax.bar_label(ax.containers[1]),
ax.legend
title = ax.set(title=('Wine Type'))
ax.title.set_fontsize(20)

# %%
sns.countplot(x ='quality_label',data=red_whine,width=0.8,color= 'red',order=['low','medium','high'])
# Out:
# <Axes: xlabel='quality_label', ylabel='count'>

# %%
fig ,axs = plt.subplots(1,2,figsize=(12,8),sharey=True)
sns.countplot(x ='quality_label',data=df_white_wine,width=0.8,color= 'grey',order=['low','medium','high'],ax=axs[0])
sns.countplot(x ='quality_label',data=df_red_wine,width=0.8,color= 'red',order=['low','medium','high'],ax=axs[1])
# Out:
# <Axes: xlabel='quality_label', ylabel='count'>

# %%
fig ,axs = plt.subplots(1,2,figsize=(10,4))

sns.boxplot(x= 'quality_label',y ='alcohol',data=df_red_wine,width=0.8,color= 'grey',order=['low','medium','high'],ax=axs[0])
sns.boxplot(x= 'quality_label',y ='pH',data=df_white_wine,width=0.8,color= 'red',order=['low','medium','high'],ax=axs[1])
# Out:
# <Axes: xlabel='quality_label', ylabel='pH'>

# %%
fig ,axs = plt.subplots(3,2,figsize=(10,4),sharex=True)

sns.lineplot(data= df_red_wine,x='quality',y='alcohol',ax=axs[0,0],color='red')
sns.lineplot(data= df_red_wine,x='quality',y='sulphates',ax=axs[0,1],color='red')

sns.lineplot(data= white_whine,x='quality',y='alcohol',ax=axs[1,0],color='grey')
sns.lineplot(data= white_whine,x='quality',y='sulphates',ax=axs[1,1],color='grey')

sns.lineplot(data= df_all_wines,x='quality',y='alcohol',ax=axs[2,0],color='green')
sns.lineplot(data= df_all_wines,x='quality',y='sulphates',ax=axs[2,1],color='green')
# Out:
# <Axes: xlabel='quality', ylabel='sulphates'>

# %%
###lineplots acidity

fig ,axs = plt.subplots(2,3,figsize=(10,4),sharex=False)

sns.lineplot(data= df_red_wine,x='quality',y='fixed acidity',ax=axs[0,0],color='red')
sns.lineplot(data= df_white_wine,x='quality',y='fixed acidity',ax=axs[0,1],color='grey')
sns.lineplot(data= df_all_wines,x='quality',y='fixed acidity',ax=axs[0,2],color='green')

sns.regplot(data= df_red_wine,x='quality',y='fixed acidity',ax=axs[1,0],color='red')
sns.regplot(data= df_white_wine,x='quality',y='fixed acidity',ax=axs[1,1],color='grey')
sns.regplot(data= df_all_wines,x='quality',y='fixed acidity',ax=axs[1,2],color='green')

# higher acidity in red wine indicates a higher quality
# lower acidity in white wine indicates a higher quality
# Out:
# <Axes: xlabel='quality', ylabel='fixed acidity'>

# %%
###lineplots volatile acidity

fig ,axs = plt.subplots(3,3,figsize=(20,12),sharex=False)

sns.lineplot(data= df_red_wine,x='quality',y='volatile acidity',ax=axs[0,0],color='darkred')
sns.lineplot(data= df_white_wine,x='quality',y='volatile acidity',ax=axs[0,1],color='grey')
sns.lineplot(data= df_all_wines,x='quality',y='volatile acidity',ax=axs[0,2],color='green')

sns.regplot(data= df_red_wine,x='quality',y='volatile acidity',ax=axs[1,0],color='darkred')
sns.regplot(data= df_white_wine,x='quality',y='volatile acidity',ax=axs[1,1],color='grey')
sns.regplot(data= df_all_wines,x='quality',y='volatile acidity',ax=axs[1,2],color='green')

sns.boxplot(data= df_red_wine,x='quality',y='volatile acidity',ax=axs[2,0],color='darkred')
sns.boxplot(data= df_white_wine,x='quality',y='volatile acidity',ax=axs[2,1],color='grey')
sns.boxplot(data= df_all_wines,x='quality',y='volatile acidity',ax=axs[2,2],color='green')


#lower volatile acidity --> higher quality
#white wine can be still high quality with a higher lower volatile acidity , red wine don't
# Out:
# <Axes: xlabel='quality', ylabel='volatile acidity'>

# %%
fig ,axs = plt.subplots(3,3,figsize=(20,12),sharex=False)

sns.lineplot(data= df_red_wine,x='quality',y='alcohol',ax=axs[0,0],color='darkred')
sns.lineplot(data= df_white_wine,x='quality',y='alcohol',ax=axs[0,1],color='grey')
sns.lineplot(data= df_all_wines,x='quality',y='alcohol',ax=axs[0,2],color='green')

sns.regplot(data= df_red_wine,x='quality',y='alcohol',ax=axs[1,0],color='darkred')
sns.regplot(data= df_white_wine,x='quality',y='alcohol',ax=axs[1,1],color='grey')
sns.regplot(data= df_all_wines,x='quality',y='alcohol',ax=axs[1,2],color='green')

sns.boxplot(data= df_red_wine,x='quality',y='alcohol',ax=axs[2,0],color='darkred')
sns.boxplot(data= df_white_wine,x='quality',y='alcohol',ax=axs[2,1],color='grey')
sns.boxplot(data= df_all_wines,x='quality',y='alcohol',ax=axs[2,2],color='green')
# Out:
# <Axes: xlabel='quality', ylabel='alcohol'>

# %%
fig ,axs = plt.subplots(3,3,figsize=(20,12),sharex=False)

sns.lineplot(data= df_red_wine,x='quality',y='density',ax=axs[0,0],color='darkred')
sns.lineplot(data= df_white_wine,x='quality',y='density',ax=axs[0,1],color='grey')
sns.lineplot(data= df_all_wines,x='quality',y='density',ax=axs[0,2],color='green')

sns.regplot(data= df_red_wine,x='quality',y='density',ax=axs[1,0],color='darkred')
sns.regplot(data= df_white_wine,x='quality',y='density',ax=axs[1,1],color='grey')
sns.regplot(data= df_all_wines,x='quality',y='density',ax=axs[1,2],color='green')

sns.boxplot(data= df_red_wine,x='quality',y='density',ax=axs[2,0],color='darkred')
sns.boxplot(data= df_white_wine,x='quality',y='density',ax=axs[2,1],color='grey')
sns.boxplot(data= df_all_wines,x='quality',y='density',ax=axs[2,2],color='green')
# Out:
# <Axes: xlabel='quality', ylabel='density'>

# %%
fig ,axs = plt.subplots(3,3,figsize=(20,12),sharex=False)

sns.lineplot(data= df_red_wine,x='quality',y='chlorides',ax=axs[0,0],color='red')
sns.lineplot(data= df_white_wine,x='quality',y='chlorides',ax=axs[0,1],color='grey')
sns.lineplot(data= df_all_wines,x='quality',y='chlorides',ax=axs[0,2],color='green')

sns.regplot(data= df_red_wine,x='quality',y='chlorides',ax=axs[1,0],color='red')
sns.regplot(data= df_white_wine,x='quality',y='chlorides',ax=axs[1,1],color='grey')
sns.regplot(data= df_all_wines,x='quality',y='chlorides',ax=axs[1,2],color='green')

sns.boxplot(data= df_red_wine,x='quality',y='chlorides',ax=axs[2,0],color='red')
sns.boxplot(data= df_white_wine,x='quality',y='chlorides',ax=axs[2,1],color='grey')
sns.boxplot(data= df_all_wines,x='quality',y='chlorides',ax=axs[2,2],color='green')
# Out:
# <Axes: xlabel='quality', ylabel='chlorides'>

# %%
###lineplots citric acid

fig ,axs = plt.subplots(2,3,figsize=(10,4),sharex=True)

sns.lineplot(data= df_red_wine,x='quality',y='citric acid',ax=axs[0,0],color='red')
sns.lineplot(data= df_white_wine,x='quality',y='citric acid',ax=axs[0,1],color='grey')
sns.lineplot(data= df_all_wines,x='quality',y='citric acid',ax=axs[0,2],color='green')

sns.regplot(data= df_red_wine,x='quality',y='citric acid',ax=axs[1,0],color='red')
sns.regplot(data= df_white_wine,x='quality',y='citric acid',ax=axs[1,1],color='grey')
sns.regplot(data= df_all_wines,x='quality',y='citric acid',ax=axs[1,2],color='green')

# a higher average in citric acid in red wine --> higher quality
# Out:
# <Axes: xlabel='quality', ylabel='citric acid'>

# %%
###lineplots residual sugar

fig ,axs = plt.subplots(2,3,figsize=(10,4),sharex=True)

sns.lineplot(data= df_red_wine,x='quality',y='residual sugar',ax=axs[0,0],color='red')
sns.lineplot(data= df_white_wine,x='quality',y='residual sugar',ax=axs[0,1],color='grey')
sns.lineplot(data= df_all_wines,x='quality',y='residual sugar',ax=axs[0,2],color='green')

sns.regplot(data= df_red_wine,x='quality',y='residual sugar',ax=axs[1,0],color='red')
sns.regplot(data= df_white_wine,x='quality',y='residual sugar',ax=axs[1,1],color='grey')
sns.regplot(data= df_all_wines,x='quality',y='residual sugar',ax=axs[1,2],color='green')
# Out:
# <Axes: xlabel='quality', ylabel='residual sugar'>

# %%
###lineplots Chlorides

fig ,axs = plt.subplots(2,3,figsize=(10,4),sharex=True)

sns.lineplot(data= df_red_wine,x='quality',y='chlorides',ax=axs[0,0],color='red')
sns.lineplot(data= df_white_wine,x='quality',y='chlorides',ax=axs[0,1],color='grey')
sns.lineplot(data= df_all_wines,x='quality',y='chlorides',ax=axs[0,2],color='green')

sns.regplot(data= df_red_wine,x='quality',y='chlorides',ax=axs[1,0],color='red')
sns.regplot(data= df_white_wine,x='quality',y='chlorides',ax=axs[1,1],color='grey')
sns.regplot(data= df_all_wines,x='quality',y='chlorides',ax=axs[1,2],color='green')

# the less chlorides the better the quality
# Out:
# <Axes: xlabel='quality', ylabel='chlorides'>

# %%
###lineplots free sulfur dioxide

fig ,axs = plt.subplots(2,3,figsize=(10,4),sharex=True)

sns.lineplot(data= df_red_wine,x='quality',y='free sulfur dioxide',ax=axs[0,0],color='red')
sns.lineplot(data= df_white_wine,x='quality',y='free sulfur dioxide',ax=axs[0,1],color='grey')
sns.lineplot(data= df_all_wines,x='quality',y='free sulfur dioxide',ax=axs[0,2],color='green')

sns.regplot(data= df_red_wine,x='quality',y='free sulfur dioxide',ax=axs[1,0],color='red')
sns.regplot(data= df_white_wine,x='quality',y='free sulfur dioxide',ax=axs[1,1],color='grey')
sns.regplot(data= df_all_wines,x='quality',y='free sulfur dioxide',ax=axs[1,2],color='green')

#for red wine: 
    #the lower the average free sulfur dioxide the higher the average quality
#for white wine
    #no correlation
# Out:
# <Axes: xlabel='quality', ylabel='free sulfur dioxide'>

# %%
###lineplots total sulfur dioxide
import matplotlib.pyplot as plt

fig ,axs = plt.subplots(2,3,figsize=(10,4),sharex=True)


sns.lineplot(data= df_red_wine,x='quality',y='total sulfur dioxide',ax=axs[0,0],color='red')
sns.lineplot(data= df_white_wine,x='quality',y='total sulfur dioxide',ax=axs[0,1],color='grey')
sns.lineplot(data= df_all_wines,x='quality',y='total sulfur dioxide',ax=axs[0,2],color='green')

sns.regplot(data= df_red_wine,x='quality',y='total sulfur dioxide',ax=axs[1,0],color='red')
sns.regplot(data= df_white_wine,x='quality',y='total sulfur dioxide',ax=axs[1,1],color='grey')
sns.regplot(data= df_all_wines,x='quality',y='total sulfur dioxide',ax=axs[1,2],color='green')



###the lower the average total sulfur dioxide the higher the average quality
# Out:
# <Axes: xlabel='quality', ylabel='total sulfur dioxide'>

# %%
###lineplots density

fig ,axs = plt.subplots(2,3,figsize=(10,4),sharex=True)

sns.lineplot(data= df_red_wine,x='quality',y='density',ax=axs[0,0],color='red')
sns.lineplot(data= df_white_wine,x='quality',y='density',ax=axs[0,1],color='grey')
sns.lineplot(data= df_all_wines,x='quality',y='density',ax=axs[0,2],color='green')

sns.regplot(data= df_red_wine,x='quality',y='density',ax=axs[1,0],color='red')
sns.regplot(data= df_white_wine,x='quality',y='density',ax=axs[1,1],color='grey')
sns.regplot(data= df_all_wines,x='quality',y='density',ax=axs[1,2],color='green')

###the lower the average density the higher the average quality
# Out:
# <Axes: xlabel='quality', ylabel='density'>

# %%
###lineplots pH

fig ,axs = plt.subplots(2,3,figsize=(10,4),sharex=True)

sns.lineplot(data= df_red_wine,x='quality',y='pH',ax=axs[0,0],color='red')
sns.lineplot(data= df_white_wine,x='quality',y='pH',ax=axs[0,1],color='grey')
sns.lineplot(data= df_all_wines,x='quality',y='pH',ax=axs[0,2],color='green')

sns.regplot(data= df_red_wine,x='quality',y='pH',ax=axs[1,0],color='red')
sns.regplot(data= df_white_wine,x='quality',y='pH',ax=axs[1,1],color='grey')
sns.regplot(data= df_all_wines,x='quality',y='pH',ax=axs[1,2],color='green')

#for red wine
    #the lower the average pH the higher the average quality
#for white wine
    #the higher the average pH the higher the average quality
# Out:
# <Axes: xlabel='quality', ylabel='pH'>

# %%
###lineplots sulphates

fig ,axs = plt.subplots(2,3,figsize=(10,4),sharex=True)

sns.lineplot(data= df_red_wine,x='quality',y='sulphates',ax=axs[0,0],color='red')
sns.lineplot(data= df_white_wine,x='quality',y='sulphates',ax=axs[0,1],color='grey')
sns.lineplot(data= df_all_wines,x='quality',y='sulphates',ax=axs[0,2],color='green')

sns.regplot(data= df_red_wine,x='quality',y='sulphates',ax=axs[1,0],color='red')
sns.regplot(data= df_white_wine,x='quality',y='sulphates',ax=axs[1,1],color='grey')
sns.regplot(data= df_all_wines,x='quality',y='sulphates',ax=axs[1,2],color='green')

#for red wine:
    #the higher the average sulphates the higher the average quality
#for white wine
# Out:
# <Axes: xlabel='quality', ylabel='sulphates'>

# %%
###lineplots alcohol

fig ,axs = plt.subplots(2,3,figsize=(10,4),sharex=True)

sns.lineplot(data= df_red_wine,x='quality',y='alcohol',ax=axs[0,0],color='red')
sns.lineplot(data= df_white_wine,x='quality',y='alcohol',ax=axs[0,1],color='grey')
sns.lineplot(data= df_all_wines,x='quality',y='alcohol',ax=axs[0,2],color='green')

sns.regplot(data= df_red_wine,x='quality',y='alcohol',ax=axs[1,0],color='red')
sns.regplot(data= df_white_wine,x='quality',y='alcohol',ax=axs[1,1],color='grey')
sns.regplot(data= df_all_wines,x='quality',y='alcohol',ax=axs[1,2],color='green')

#for all wines
    #the higher the average alcohol % the higher the average perceived quality
# Out:
# <Axes: xlabel='quality', ylabel='alcohol'>

# %%
fig ,axs = plt.subplots(2,3,figsize=(10,4),sharex=True)

sns.lineplot(data= df_red_wine,x='quality',y='alcohol',ax=axs[0,0],color='red')
sns.lineplot(data= df_white_wine,x='quality',y='alcohol',ax=axs[0,1],color='grey')
sns.lineplot(data= df_all_wines,x='quality',y='alcohol',ax=axs[0,2],color='green')

sns.regplot(data= df_red_wine,x='quality',y='alcohol',ax=axs[1,0],color='red')
sns.regplot(data= df_white_wine,x='quality',y='alcohol',ax=axs[1,1],color='grey')
sns.regplot(data= df_all_wines,x='quality',y='alcohol',ax=axs[1,2],color='green')
# Out:
# <Axes: xlabel='quality', ylabel='alcohol'>

# %%
p1= sns.relplot(data=df_all_wines,x='alcohol',y="density",hue='type')
# Out:
# /Users/Lucasmeissner/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df_all_wines.head(25)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4             0.700         0.00             1.9      0.076
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 3            11.2             0.280         0.56             1.9      0.075
# 4             7.4             0.660         0.00             1.8      0.075
# 5             7.9             0.600         0.06             1.6      0.069
# 6             7.3             0.650         0.00             1.2      0.065
# 7             7.8             0.580         0.02             2.0      0.073
# 8             7.5             0.500         0.36             6.1      0.071
# 9             6.7             0.580         0.08             1.8      0.097
# 10            5.6             0.615         0.00             1.6      0.089
# ...

# %%
print(df_all_wines['quality'].describe())

#fixed acidity in g(tartaricacid)/dm3 = continous (range = 3,8- 15.9)
#volatile acidity in g(aceticacid)/dm3 = continous (range= 0.08-1.58)
#citric acid in g/dm3 = continous (range= 0.00- 1.66)
#residual sugar in g/dm3 = continous (range = 0,6- 65.8)
#chlorides in g(sodiumchloride)/dm3 = continous (range =0.009-0.611)
#free sulfur dioxide in mg/dm3  = continous (range= 1.0 - 289.0)
#total sulfur dioxide in mg/dm3  = continous (range= 6.0 - 440.0)
#density in g/cm3 = continous (range= 0.98711 - 1.03898)
#pH (from ph- scale, water = 7ph, <7ph = acidy,>7ph = basic)= continous (range= 2.72-4.01)
#sulphates in g(potassiumsulphate)/dm3 = continous (range= 0.22-2.0)
#alcohol = continous (range= 8.0-14.9)
#quality = categorical (range= 3-9)
# Out:
# count    5320.000000
# mean        5.795677
# std         0.879772
# min         3.000000
# 25%         5.000000
# 50%         6.000000
# 75%         6.000000
# max         9.000000
# Name: quality, dtype: float64

# %%
df_red_wine.hist(bins=15, color='red', edgecolor='black', linewidth=1.0, xlabelsize=8, ylabelsize=8, grid=False)

plt.tight_layout(rect=(0, 0, 1.2, 1.2))

rt = plt.suptitle('Red Wine Univariate Plots', x=0.65, y=1.25, fontsize=15)

# %%
df_white_wine.hist(bins=15, color='grey', edgecolor='black', linewidth=1.0, xlabelsize=8, ylabelsize=8, grid=False)

plt.tight_layout(rect=(0, 0, 1.2, 1.2))

rt = plt.suptitle('White Wine Univariate Plots', x=0.65, y=1.25, fontsize=15)

# %%
fig ,axs = plt.subplots(1,2,figsize=(10,4))

r1 = sns.histplot(data=df_red_wine, x= 'residual sugar',color='red',ax=axs[0],bins=15,legend=True,edgecolor='black',cbar=True)
r2= sns.histplot(data=df_white_wine, x= 'residual sugar',color='white',ax=axs[1],bins=15,legend=True, edgecolor='black',cbar=True)

r1.set_xlabel('Residual Sugar')
r2.set_xlabel('Residual Sugar')

r1.set_ylabel('Frequency')
r2.set_ylabel('Frequency')

r1.set(ylim=(0,2500))
r2.set(ylim=(0,2500))

r1.set(title=('Red Wine'))
r2.set(title=('White Wine'))

plt.suptitle('Residual Sugar Content in Wine', fontsize=15)
# Out:
# Text(0.5, 0.98, 'Residual Sugar Content in Wine')

# %%
data = df_all_wines

corr = df_all_wines[['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol','quality']].corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap="coolwarm_r",
    square=True,
    annot=True,
)

ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
)
sns.set(rc = {'figure.figsize':(15,8)})

# %%
data = df_white_wine

corr = df_white_wine[['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol','quality']].corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap="coolwarm_r",
    square=True,
    annot=True,
)

ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
)
sns.set(rc = {'figure.figsize':(15,8)})

# %%
def barplot_chart_loop(data,x):

    for i,col in enumerate(data.columns):
        plt.figure(i)
        sns.barplot(x=x,y=col,data=data)
        sns.set(rc = {'figure.figsize':(15,8)})

    return

# %%
df_white_wine['fixed acidity'].describe()
# Out:
# count    3961.000000
# mean        6.839346
# std         0.866860
# min         3.800000
# 25%         6.300000
# 50%         6.800000
# 75%         7.300000
# max        14.200000
# Name: fixed acidity, dtype: float64

# %%
def boxplot_chart_loop(data,x,y):

    for i,col in enumerate(data.columns):
        plt.figure(i)
        sns.boxplot(x=x,y=col,data=data)
        sns.set(rc = {'figure.figsize':(15,8)})
    return

# %%
def barplot_chart_loop(data,x,y):

    for i,col in enumerate(data.columns):
        plt.figure(i)
        sns.barplot(x=x,y=col,data=data)
        sns.set(rc = {'figure.figsize':(15,8)})
    return

# %%
def regplot_chart_loop(data,x,y):

    for i,col in enumerate(data.columns):
        plt.figure(i)
        sns.regplot(x=x,y=col,data=data)
        sns.set(rc = {'figure.figsize':(15,8)})
    return

# %%
g = sns.JointGrid(space=0.9,marginal_ticks=True)
title = 'Red Wine Qiality-Sulphates'
plt.suptitle(title, y = 1.05)
x, y =df_red_wine.quality, df_red_wine.sulphates
sns.scatterplot(x=x, y=y, ax=g.ax_joint, color='red', s=100, alpha=0.4)
sns.histplot(x=x, ax=g.ax_marg_x, color='red',bins=[3,4,5,6,7,8],binwidth=0.5)
sns.histplot(y=y, ax=g.ax_marg_y, color='red',binwidth=0.2,binrange=(0.3,1.2))
sns.despine(left=False, bottom=False, top=False, right=False)
g.ax_marg_y.tick_params(labelleft=True,color='black',which='both',direction='out',left=True)
g.ax_marg_x.tick_params(labelbottom=True,color='black',bottom=True,left=True)
g.ax_marg_y.set_xlim(0)
g.ax_marg_x.set_ylim(0)
# Out:
# (0.0, 605.85)

# %%
g = sns.JointGrid(space=0.9,marginal_ticks=True)
title = 'Red Wine Qiality-Sulphates'
plt.suptitle(title, y = 1.05)
x, y =df_white_wine.quality, df_white_wine.sulphates
sns.scatterplot(x=x, y=y, ax=g.ax_joint, color='darkred', s=100, alpha=0.4)
sns.histplot(x=x, ax=g.ax_marg_x, color='darkred',bins=[3,4,5,6,7,8],binwidth=0.5)
sns.histplot(y=y, ax=g.ax_marg_y, color='darkred',binwidth=0.2,binrange=(0.25,1.2))
sns.despine(left=False, bottom=False, top=False, right=False)
g.ax_marg_y.tick_params(labelleft=True,color='black',which='both',direction='out',left=True)
g.ax_marg_x.tick_params(labelbottom=True,color='black',bottom=True,left=True)
g.ax_marg_y.set_xlim(0)
g.ax_marg_x.set_ylim(0)

sns.set_theme(context='notebook')
sns.set_style('white')

# %%
g= sns.scatterplot(df_red_wine,x='alcohol',y='sulphates',hue='quality_label',s=100,palette='deep')
g.tick_params(bottom=True,left=True)
g.set_xlim(8)
# Out:
# (8.0, 15.225)

# %%
g = sns.jointplot(data=df_red_wine,color='darkred', x='quality', y='sulphates', marginal_ticks=True,
            height=8, space=0.3, ratio=2,
              joint_kws={'s': 100}, 
              marginal_kws={'bins': 6})

g.ax_marg_y.tick_params(labelleft=True,color='black',which='both',direction='out',left=True)
g.ax_marg_x.tick_params(labelbottom=True,color='black',which='both',direction='out',left=True)



sns.despine(left=False, bottom=False, top=False, right=False)

plt.suptitle('Red Wine Sulphates Quality', fontsize=15)
plt.show()

# %%
fig ,axs = plt.subplots(1,2,figsize=(10,4))

r1 = sns.histplot(data=df_red_wine, x= 'residual sugar',color='red',ax=axs[0],bins=15,legend=True,edgecolor='black',cbar=True)
r2= sns.histplot(data=df_white_wine, x= 'residual sugar',color='white',ax=axs[1],bins=15,legend=True, edgecolor='black',cbar=True)

r1.set_xlabel('Residual Sugar')
r2.set_xlabel('Residual Sugar')

r1.set_ylabel('Frequency')
r2.set_ylabel('Frequency')

r1.set(ylim=(0,2500))
r2.set(ylim=(0,2500))

r1.set(title=('Red Wine'))
r2.set(title=('White Wine'))

plt.suptitle('Residual Sugar Content in Wine', fontsize=15)
# Out:
# Text(0.5, 0.98, 'Residual Sugar Content in Wine')

# %%
from scipy import stats

F, p = stats.f_oneway(df_red_wine[df_red_wine['quality_label'] == 'low']['alcohol'],
df_red_wine[df_red_wine['quality_label'] == 'medium']['alcohol'],
df_red_wine[df_red_wine['quality_label'] == 'high']['alcohol'])
print('ANOVA test for mean alcohol levels across wine samples with different quality ratings')
print('F Statistic:', F, '\tp-value:', p)

### statistical significance is there
# Out:
# ANOVA test for mean alcohol levels across wine samples with different quality ratings
# F Statistic: 187.64407258778138 	p-value: 1.1419488265314005e-72

# %%
F, p = stats.f_oneway(df_red_wine[df_red_wine['quality_label'] == 'low']['density'],
df_red_wine[df_red_wine['quality_label'] == 'medium']['density'],
df_red_wine[df_red_wine['quality_label'] == 'high']['density'])
print('ANOVA test for mean density levels across wine samples with different quality ratings')
print('F Statistic:', F, '\tp-value:', p)

### statistical significance is there
# Out:
# ANOVA test for mean density levels across wine samples with different quality ratings
# F Statistic: 24.519858591738284 	p-value: 3.460972032763999e-11

# %%
F, p = stats.f_oneway(df_red_wine[df_red_wine['quality_label'] == 'low']['chlorides'],
df_red_wine[df_red_wine['quality_label'] == 'medium']['chlorides'],
df_red_wine[df_red_wine['quality_label'] == 'high']['chlorides'])
print('ANOVA test for mean chlorides levels across wine samples with different quality ratings')
print('F Statistic:', F, '\tp-value:', p)

### statistical significance is there
# Out:
# ANOVA test for mean chlorides levels across wine samples with different quality ratings
# F Statistic: 9.859608363198346 	p-value: 5.608704400164339e-05

# %%
F, p = stats.f_oneway(df_red_wine[df_red_wine['quality_label'] == 'low']['volatile acidity'],
df_red_wine[df_red_wine['quality_label'] == 'medium']['volatile acidity'],
df_red_wine[df_red_wine['quality_label'] == 'high']['volatile acidity'])
print('ANOVA test for mean volatile acidity levels across wine samples with different quality ratings')
print('F Statistic:', F, '\tp-value:', p)

### statistical significance is there
# Out:
# ANOVA test for mean volatile acidity levels across wine samples with different quality ratings
# F Statistic: 81.95632590559691 	p-value: 2.5063302469762624e-34

# %%
F, p = stats.f_oneway(
df_red_wine[df_red_wine['quality'] == 3]['alcohol'],
df_red_wine[df_red_wine['quality'] == 4]['alcohol'],
df_red_wine[df_red_wine['quality'] == 5]['alcohol'],
df_red_wine[df_red_wine['quality'] == 6]['alcohol'],
df_red_wine[df_red_wine['quality'] == 7]['alcohol'],
df_red_wine[df_red_wine['quality'] == 8]['alcohol'],
df_red_wine[df_red_wine['quality'] == 9]['alcohol'])
print('ANOVA test for mean alcohol levels across wine samples with different quality ratings')
print('F Statistic:', F, '\tp-value:', p)
# Out:
# ANOVA test for mean alcohol levels across wine samples with different quality ratings
# F Statistic: nan 	p-value: nan
# /Users/Lucasmeissner/anaconda3/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4133: DegenerateDataWarning: at least one input has length 0
#   warnings.warn(stats.DegenerateDataWarning('at least one input '
